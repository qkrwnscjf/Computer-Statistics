# %%
# 첨부 파일을 이용하여, Expense 에 대한 Income 이 영향이 있는 지 그 관계를 선형 회귀 모형으로 표현하고,

# lmplot을 이용하여 회귀선과 산점도를 plot으로 그리시오.

# %%
import LinearRegression as ln
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
student = pd.read_csv("student1.csv")
student.head()
# Out:
#    Age  Income  Expense
# 0   25     170       67
# 1   28     177       62
# 2   20     165       53
# 3   16     150       48
# 4   19     160       58

# %%
sns.lmplot(x = 'Income', y = 'Expense', data = student, ci = 95)
#선형 회귀선과 산점도의 분포를 보았을 때, 수입(독립 변수 - income)이 높을 수록 지출(종속 변수 - expense)이 높다?!
